# %%
import json
import pandas as pd
import os
import glob
from tqdm import tqdm
import re
from pandas.io.json import json_normalize
from datetime import datetime
import numpy as np

# %%
adam = pd.read_csv('adam_summary.csv')
pete = pd.read_csv('pete_summary.csv')
jason = pd.read_csv('jason_summary.csv')
jeremy = pd.read_csv('jeremy_summary.csv')

# %%
all_overview = pd.concat([adam, pete, jason, jeremy], axis = 0)
all_overview
# Out:
#     Unnamed: 0         day             name  total_distance   avg_pace  \
# 0            0  2016-02-15      Adam Kimble           55.62  14.216667
# 1            1  2016-02-16      Adam Kimble           19.13  16.350000
# 2            2  2016-02-17      Adam Kimble           58.57  13.908333
# 3            3  2016-02-18      Adam Kimble           36.26  15.416667
# 4            4  2016-02-19      Adam Kimble           48.62  18.833333
# 5            5  2016-02-20      Adam Kimble           40.17  18.025000
# 6            6  2016-02-21      Adam Kimble           30.05  17.875000
# 7            7  2016-02-22      Adam Kimble           39.77  16.833333
# 8            8  2016-02-26      Adam Kimble           41.20  14.716667
# 9            9  2016-02-27      Adam Kimble           50.09  15.433333
# 10          10  2016-02-28      Adam Kimble           38.32  15.600000
# 11          11  2016-02-29      Adam Kimble           47.39  13.733333
# ...

# %%
all_overview.to_csv("combined_overview.csv")
